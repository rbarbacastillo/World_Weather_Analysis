# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=79d7a89f22cdb95a08fb0f49039f8811

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | fortuna
# Processing Record 10 of Set 1 | tabuk
# Processing Record 11 of Set 1 | kommunar
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 14 of Set 1 | huarmey
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | boa vista
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | boysun
# Processing Record 22 of Set 1 | aden
# Processing Record 23 of Set 1 | beirut
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | urucara
# Processing Record 26 of Set 1 | sindor
# Processing Record 27 of Set 1 | jesus carranza
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | port hedland
# Processing Record 31 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | los llanos de aridane
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | mizdah
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 1 | nieuw amsterdam
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | luanda
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | champerico
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | chitral
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | baghdad
# Processing Record 50 of Set 1 | loandjili
# Processing Record 1 of Set 2 | axim
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | burica
# City not found. Skipping...
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | namatanai
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | makakilo city
# Processing Record 11 of Set 2 | brae
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | honiara
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | polovinnoye
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | taman
# Processing Record 22 of Set 2 | kranjska gora
# Processing Record 23 of Set 2 | valparaiso
# Processing Record 24 of Set 2 | meulaboh
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | grindavik
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | bathsheba
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | yumen
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | adrar
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | abu kamal
# Processing Record 37 of Set 2 | samarai
# Processing Record 38 of Set 2 | almaznyy
# Processing Record 39 of Set 2 | magadan
# Processing Record 40 of Set 2 | palmer
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | robertsport
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | spasskoye
# Processing Record 49 of Set 2 | scarborough
# Processing Record 50 of Set 2 | san andres
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | orchard homes
# Processing Record 4 of Set 3 | richards bay
# Processing Record 5 of Set 3 | amahai
# Processing Record 6 of Set 3 | havoysund
# Processing Record 7 of Set 3 | itaituba
# Processing Record 8 of Set 3 | umuarama
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | avera
# Processing Record 12 of Set 3 | imbituba
# Processing Record 13 of Set 3 | haines junction
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | penzance
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | quelimane
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | santa isabel do rio negro
# Processing Record 24 of Set 3 | guaira
# Processing Record 25 of Set 3 | tsuyama
# Processing Record 26 of Set 3 | balkanabat
# Processing Record 27 of Set 3 | kerrville
# Processing Record 28 of Set 3 | bunbury
# Processing Record 29 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | cabo san lucas
# Processing Record 32 of Set 3 | haapiti
# Processing Record 33 of Set 3 | brookings
# Processing Record 34 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 3 | poum
# Processing Record 36 of Set 3 | hami
# Processing Record 37 of Set 3 | sibolga
# Processing Record 38 of Set 3 | mandera
# Processing Record 39 of Set 3 | milkovo
# Processing Record 40 of Set 3 | turkistan
# Processing Record 41 of Set 3 | buraydah
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | ambilobe
# Processing Record 44 of Set 3 | semenivka
# Processing Record 45 of Set 3 | emerald
# Processing Record 46 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | kirakira
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | phan thiet
# Processing Record 1 of Set 4 | san vicente
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 4 | marzuq
# Processing Record 8 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | totma
# Processing Record 12 of Set 4 | port keats
# Processing Record 13 of Set 4 | novo aripuana
# Processing Record 14 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 4 | tautira
# Processing Record 16 of Set 4 | novobirilyussy
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | tura
# Processing Record 19 of Set 4 | constitucion
# Processing Record 20 of Set 4 | jumla
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | acapulco
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | margate
# Processing Record 25 of Set 4 | cairns
# Processing Record 26 of Set 4 | yuanping
# Processing Record 27 of Set 4 | salamiyah
# Processing Record 28 of Set 4 | waingapu
# Processing Record 29 of Set 4 | dingle
# Processing Record 30 of Set 4 | la ronge
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | ponta do sol
# Processing Record 34 of Set 4 | whitehorse
# Processing Record 35 of Set 4 | rawson
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | shimanovsk
# Processing Record 38 of Set 4 | mecca
# Processing Record 39 of Set 4 | erenhot
# Processing Record 40 of Set 4 | hvolsvollur
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | saint-dizier
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | treinta y tres
# Processing Record 45 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 46 of Set 4 | north bend
# Processing Record 47 of Set 4 | olafsvik
# Processing Record 48 of Set 4 | fort saint james
# Processing Record 49 of Set 4 | vilhena
# Processing Record 50 of Set 4 | portland
# Processing Record 1 of Set 5 | wamba
# Processing Record 2 of Set 5 | vestmannaeyjar
# Processing Record 3 of Set 5 | lokoja
# Processing Record 4 of Set 5 | takoradi
# Processing Record 5 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 7 of Set 5 | oswiecim
# Processing Record 8 of Set 5 | qazvin
# Processing Record 9 of Set 5 | aykhal
# Processing Record 10 of Set 5 | lac du bonnet
# Processing Record 11 of Set 5 | mahebourg
# Processing Record 12 of Set 5 | nenjiang
# Processing Record 13 of Set 5 | belmonte
# Processing Record 14 of Set 5 | tuy hoa
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | den helder
# Processing Record 18 of Set 5 | kuching
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | artesia
# Processing Record 21 of Set 5 | povenets
# Processing Record 22 of Set 5 | barahona
# Processing Record 23 of Set 5 | malinovskiy
# Processing Record 24 of Set 5 | tombouctou
# Processing Record 25 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 5 | filadelfia
# Processing Record 27 of Set 5 | bay roberts
# Processing Record 28 of Set 5 | nuuk
# Processing Record 29 of Set 5 | gallup
# Processing Record 30 of Set 5 | loei
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | gayny
# Processing Record 33 of Set 5 | cookeville
# Processing Record 34 of Set 5 | koslan
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | akureyri
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | suraabad
# Processing Record 40 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 5 | bam
# Processing Record 42 of Set 5 | idaho falls
# Processing Record 43 of Set 5 | svetlogorsk
# Processing Record 44 of Set 5 | zhanakorgan
# Processing Record 45 of Set 5 | berlevag
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | dir
# Processing Record 50 of Set 5 | necochea
# Processing Record 1 of Set 6 | nelson bay
# Processing Record 2 of Set 6 | greenwood
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | severnyy
# Processing Record 5 of Set 6 | nara
# Processing Record 6 of Set 6 | fort nelson
# Processing Record 7 of Set 6 | ulladulla
# Processing Record 8 of Set 6 | asau
# Processing Record 9 of Set 6 | flinders
# Processing Record 10 of Set 6 | ust-koksa
# Processing Record 11 of Set 6 | ulaangom
# Processing Record 12 of Set 6 | arona
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 15 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 6 | valera
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | agadez
# Processing Record 19 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 6 | lat yao
# Processing Record 21 of Set 6 | pavilosta
# Processing Record 22 of Set 6 | aripuana
# Processing Record 23 of Set 6 | hamilton
# Processing Record 24 of Set 6 | badulla
# Processing Record 25 of Set 6 | gunjur
# Processing Record 26 of Set 6 | korla
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | chapais
# Processing Record 29 of Set 6 | cullman
# Processing Record 30 of Set 6 | zhezkazgan
# Processing Record 31 of Set 6 | kuito
# Processing Record 32 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 33 of Set 6 | kayes
# Processing Record 34 of Set 6 | port-cartier
# Processing Record 35 of Set 6 | jaru
# Processing Record 36 of Set 6 | taltal
# Processing Record 37 of Set 6 | mana
# Processing Record 38 of Set 6 | san policarpo
# Processing Record 39 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | khani
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 6 | kapit
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | edson
# Processing Record 47 of Set 6 | jacksonville
# Processing Record 48 of Set 6 | cerro largo
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | tiksi
# Processing Record 1 of Set 7 | atar
# Processing Record 2 of Set 7 | hienghene
# Processing Record 3 of Set 7 | khatanga
# Processing Record 4 of Set 7 | marion
# Processing Record 5 of Set 7 | manicore
# Processing Record 6 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 7 of Set 7 | comodoro rivadavia
# Processing Record 8 of Set 7 | dongkan
# Processing Record 9 of Set 7 | rancho palos verdes
# Processing Record 10 of Set 7 | iqaluit
# Processing Record 11 of Set 7 | roma
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | kuryk
# Processing Record 14 of Set 7 | doha
# Processing Record 15 of Set 7 | mapiripan
# Processing Record 16 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 17 of Set 7 | tucumcari
# Processing Record 18 of Set 7 | wilson
# Processing Record 19 of Set 7 | nikolskoye
# Processing Record 20 of Set 7 | jiuquan
# Processing Record 21 of Set 7 | mananara
# Processing Record 22 of Set 7 | verkhnyaya inta
# Processing Record 23 of Set 7 | ha giang
# Processing Record 24 of Set 7 | klaksvik
# Processing Record 25 of Set 7 | gemena
# Processing Record 26 of Set 7 | tabas
# Processing Record 27 of Set 7 | cayenne
# Processing Record 28 of Set 7 | qaqortoq
# Processing Record 29 of Set 7 | san carlos de bariloche
# Processing Record 30 of Set 7 | kasiri
# Processing Record 31 of Set 7 | kahului
# Processing Record 32 of Set 7 | popondetta
# Processing Record 33 of Set 7 | hanyang
# Processing Record 34 of Set 7 | harindanga
# Processing Record 35 of Set 7 | laela
# Processing Record 36 of Set 7 | kununurra
# Processing Record 37 of Set 7 | cabedelo
# Processing Record 38 of Set 7 | luganville
# Processing Record 39 of Set 7 | chokwe
# Processing Record 40 of Set 7 | muros
# Processing Record 41 of Set 7 | miraflores
# Processing Record 42 of Set 7 | colac
# Processing Record 43 of Set 7 | kita
# Processing Record 44 of Set 7 | mareeba
# Processing Record 45 of Set 7 | bafq
# Processing Record 46 of Set 7 | jobat
# Processing Record 47 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | eagle pass
# Processing Record 49 of Set 7 | kuznechikha
# Processing Record 50 of Set 7 | santa maria
# Processing Record 1 of Set 8 | wanning
# Processing Record 2 of Set 8 | longview
# Processing Record 3 of Set 8 | lander
# Processing Record 4 of Set 8 | ormara
# Processing Record 5 of Set 8 | sorland
# Processing Record 6 of Set 8 | bonfim
# Processing Record 7 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 8 | general pico
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | hauge
# Processing Record 11 of Set 8 | okhtyrka
# Processing Record 12 of Set 8 | port elizabeth
# Processing Record 13 of Set 8 | katav-ivanovsk
# Processing Record 14 of Set 8 | corredor
# Processing Record 15 of Set 8 | srednekolymsk
# Processing Record 16 of Set 8 | banyo
# Processing Record 17 of Set 8 | orlik
# Processing Record 18 of Set 8 | nkhotakota
# Processing Record 19 of Set 8 | athabasca
# Processing Record 20 of Set 8 | smoky lake
# Processing Record 21 of Set 8 | lasalgaon
# Processing Record 22 of Set 8 | sabinas hidalgo
# Processing Record 23 of Set 8 | bow island
# Processing Record 24 of Set 8 | vostok
# Processing Record 25 of Set 8 | san jose
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | wanaka
# Processing Record 28 of Set 8 | ndele
# Processing Record 29 of Set 8 | coquimbo
# Processing Record 30 of Set 8 | laguna
# Processing Record 31 of Set 8 | vila do maio
# Processing Record 32 of Set 8 | arman
# Processing Record 33 of Set 8 | strelka
# Processing Record 34 of Set 8 | ilhabela
# Processing Record 35 of Set 8 | crotone
# Processing Record 36 of Set 8 | mwinilunga
# Processing Record 37 of Set 8 | tarakan
# Processing Record 38 of Set 8 | taoudenni
# Processing Record 39 of Set 8 | waipawa
# Processing Record 40 of Set 8 | sambava
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | shagonar
# Processing Record 43 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 8 | olinda
# Processing Record 45 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 8 | broome
# Processing Record 47 of Set 8 | mokobeng
# Processing Record 48 of Set 8 | valdosta
# Processing Record 49 of Set 8 | skibbereen
# Processing Record 50 of Set 8 | fairbanks
# Processing Record 1 of Set 9 | berdigestyakh
# Processing Record 2 of Set 9 | tahta
# Processing Record 3 of Set 9 | corn island
# Processing Record 4 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 9 | verkhnyaya toyma
# Processing Record 6 of Set 9 | iskateley
# Processing Record 7 of Set 9 | kijang
# Processing Record 8 of Set 9 | kodiak
# Processing Record 9 of Set 9 | lebu
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | san juan
# Processing Record 12 of Set 9 | ereymentau
# Processing Record 13 of Set 9 | husavik
# Processing Record 14 of Set 9 | dossor
# Processing Record 15 of Set 9 | duki
# Processing Record 16 of Set 9 | gimli
# Processing Record 17 of Set 9 | prince rupert
# Processing Record 18 of Set 9 | porto santo
# Processing Record 19 of Set 9 | booue
# Processing Record 20 of Set 9 | taft
# Processing Record 21 of Set 9 | san rafael del sur
# Processing Record 22 of Set 9 | deputatskiy
# Processing Record 23 of Set 9 | hualmay
# Processing Record 24 of Set 9 | sitio novo do tocantins
# Processing Record 25 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 9 | prado
# Processing Record 27 of Set 9 | pushkino
# Processing Record 28 of Set 9 | tucuman
# Processing Record 29 of Set 9 | harrison
# Processing Record 30 of Set 9 | kaeo
# Processing Record 31 of Set 9 | bichena
# Processing Record 32 of Set 9 | placerville
# Processing Record 33 of Set 9 | sistranda
# Processing Record 34 of Set 9 | yulara
# Processing Record 35 of Set 9 | tiznit
# Processing Record 36 of Set 9 | toyooka
# Processing Record 37 of Set 9 | vermillion
# Processing Record 38 of Set 9 | humberto de campos
# Processing Record 39 of Set 9 | sohag
# Processing Record 40 of Set 9 | spencer
# Processing Record 41 of Set 9 | canico
# Processing Record 42 of Set 9 | goderich
# Processing Record 43 of Set 9 | ialibu
# Processing Record 44 of Set 9 | awbari
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | fukue
# Processing Record 47 of Set 9 | naze
# Processing Record 48 of Set 9 | golynki
# Processing Record 49 of Set 9 | jiangyou
# Processing Record 50 of Set 9 | phaltan
# Processing Record 1 of Set 10 | hailar
# Processing Record 2 of Set 10 | tabat
# Processing Record 3 of Set 10 | wahiawa
# Processing Record 4 of Set 10 | tilichiki
# Processing Record 5 of Set 10 | karratha
# Processing Record 6 of Set 10 | esna
# Processing Record 7 of Set 10 | san diego de la union
# Processing Record 8 of Set 10 | zhetybay
# City not found. Skipping...
# Processing Record 9 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | kortkeros
# Processing Record 11 of Set 10 | alice springs
# Processing Record 12 of Set 10 | ixtapa
# Processing Record 13 of Set 10 | borogontsy
# Processing Record 14 of Set 10 | marsa matruh
# Processing Record 15 of Set 10 | porto novo
# Processing Record 16 of Set 10 | moramanga
# Processing Record 17 of Set 10 | mercedes
# Processing Record 18 of Set 10 | vao
# Processing Record 19 of Set 10 | marabba
# Processing Record 20 of Set 10 | catamarca
# Processing Record 21 of Set 10 | berezovyy
# Processing Record 22 of Set 10 | camacha
# Processing Record 23 of Set 10 | pombas
# Processing Record 24 of Set 10 | belaya gora
# Processing Record 25 of Set 10 | brokopondo
# Processing Record 26 of Set 10 | marsh harbour
# Processing Record 27 of Set 10 | lethem
# Processing Record 28 of Set 10 | guerrero negro
# Processing Record 29 of Set 10 | maceio
# Processing Record 30 of Set 10 | ilulissat
# Processing Record 31 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 32 of Set 10 | sobolevo
# Processing Record 33 of Set 10 | benton harbor
# Processing Record 34 of Set 10 | aswan
# Processing Record 35 of Set 10 | victoria point
# Processing Record 36 of Set 10 | nyimba
# Processing Record 37 of Set 10 | peterhead
# Processing Record 38 of Set 10 | bereda
# Processing Record 39 of Set 10 | villa bruzual
# Processing Record 40 of Set 10 | harrisonburg
# Processing Record 41 of Set 10 | stokmarknes
# Processing Record 42 of Set 10 | hofn
# Processing Record 43 of Set 10 | matara
# Processing Record 44 of Set 10 | templin
# Processing Record 45 of Set 10 | santa rosalia
# Processing Record 46 of Set 10 | masallatah
# Processing Record 47 of Set 10 | kashi
# Processing Record 48 of Set 10 | bonavista
# Processing Record 49 of Set 10 | licheng
# Processing Record 50 of Set 10 | mazagao
# Processing Record 1 of Set 11 | dabrowa tarnowska
# Processing Record 2 of Set 11 | sioux lookout
# Processing Record 3 of Set 11 | bezhanitsy
# Processing Record 4 of Set 11 | dzerzhinskoye
# Processing Record 5 of Set 11 | ushibuka
# Processing Record 6 of Set 11 | tambopata
# Processing Record 7 of Set 11 | weligama
# Processing Record 8 of Set 11 | madarounfa
# Processing Record 9 of Set 11 | nishihara
# Processing Record 10 of Set 11 | tongchuan
# Processing Record 11 of Set 11 | beira
# Processing Record 12 of Set 11 | karpogory
# Processing Record 13 of Set 11 | chuzhou
# Processing Record 14 of Set 11 | dunedin
# Processing Record 15 of Set 11 | teguldet
# Processing Record 16 of Set 11 | narrabri
# Processing Record 17 of Set 11 | saint-paul
# Processing Record 18 of Set 11 | bud
# Processing Record 19 of Set 11 | andenes
# Processing Record 20 of Set 11 | charters towers
# Processing Record 21 of Set 11 | luderitz
# Processing Record 22 of Set 11 | tricase
# Processing Record 23 of Set 11 | lagoa
# Processing Record 24 of Set 11 | san patricio
# Processing Record 25 of Set 11 | puerto del rosario
# Processing Record 26 of Set 11 | fairview
# Processing Record 27 of Set 11 | sao pedro do sul
# Processing Record 28 of Set 11 | san luis
# Processing Record 29 of Set 11 | chalisgaon
# Processing Record 30 of Set 11 | ginda
# Processing Record 31 of Set 11 | havelock
# Processing Record 32 of Set 11 | utena
# Processing Record 33 of Set 11 | mayo
# Processing Record 34 of Set 11 | kloulklubed
# Processing Record 35 of Set 11 | san cristobal
# Processing Record 36 of Set 11 | gwanda
# Processing Record 37 of Set 11 | half moon bay
# Processing Record 38 of Set 11 | yarmouth
# Processing Record 39 of Set 11 | camana
# Processing Record 40 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 11 | papetoai
# Processing Record 42 of Set 11 | rantepao
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | kobojango
# City not found. Skipping...
# Processing Record 45 of Set 11 | troitsko-pechorsk
# Processing Record 46 of Set 11 | valjala
# City not found. Skipping...
# Processing Record 47 of Set 11 | werneck
# Processing Record 48 of Set 11 | tecoanapa
# Processing Record 49 of Set 11 | obodivka
# Processing Record 50 of Set 11 | sao jose da coroa grande
# Processing Record 1 of Set 12 | alofi
# Processing Record 2 of Set 12 | nizhniy kuranakh
# Processing Record 3 of Set 12 | alasehir
# Processing Record 4 of Set 12 | ahtopol
# Processing Record 5 of Set 12 | kavaratti
# Processing Record 6 of Set 12 | halifax
# Processing Record 7 of Set 12 | nizhnevartovsk
# Processing Record 8 of Set 12 | seoul
# Processing Record 9 of Set 12 | parrita
# Processing Record 10 of Set 12 | kieta
# Processing Record 11 of Set 12 | faanui
# Processing Record 12 of Set 12 | syracuse
# Processing Record 13 of Set 12 | ornskoldsvik
# Processing Record 14 of Set 12 | lata
# Processing Record 15 of Set 12 | yenagoa
# Processing Record 16 of Set 12 | krasnozerskoye
# Processing Record 17 of Set 12 | les cayes
# Processing Record 18 of Set 12 | saint-augustin
# Processing Record 19 of Set 12 | pimenta bueno
# Processing Record 20 of Set 12 | esperance
# Processing Record 21 of Set 12 | raub
# Processing Record 22 of Set 12 | sumbe
# Processing Record 23 of Set 12 | dalbandin
# Processing Record 24 of Set 12 | christchurch
# Processing Record 25 of Set 12 | hambantota
# Processing Record 26 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 12 | larsnes
# Processing Record 28 of Set 12 | imeni poliny osipenko
# Processing Record 29 of Set 12 | benguela
# Processing Record 30 of Set 12 | parkent
# Processing Record 31 of Set 12 | udachnyy
# Processing Record 32 of Set 12 | college
# Processing Record 33 of Set 12 | moron
# Processing Record 34 of Set 12 | xining
# Processing Record 35 of Set 12 | mali
# Processing Record 36 of Set 12 | saint-georges
# Processing Record 37 of Set 12 | seymchan
# Processing Record 38 of Set 12 | marawi
# Processing Record 39 of Set 12 | lompoc
# Processing Record 40 of Set 12 | porto belo
# Processing Record 41 of Set 12 | evensk
# Processing Record 42 of Set 12 | finnsnes
# Processing Record 43 of Set 12 | severinia
# Processing Record 44 of Set 12 | inhambane
# Processing Record 45 of Set 12 | kupang
# Processing Record 46 of Set 12 | hastings
# Processing Record 47 of Set 12 | jiutai
# Processing Record 48 of Set 12 | sonepur
# Processing Record 49 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 12 | amapa
# Processing Record 1 of Set 13 | montanhas
# Processing Record 2 of Set 13 | narsaq
# Processing Record 3 of Set 13 | grand bank
# Processing Record 4 of Set 13 | lasa
# Processing Record 5 of Set 13 | shimoda
# Processing Record 6 of Set 13 | sangar
# Processing Record 7 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 13 | okhotsk
# Processing Record 9 of Set 13 | ryotsu
# Processing Record 10 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 13 | ouegoa
# Processing Record 12 of Set 13 | muromtsevo
# Processing Record 13 of Set 13 | labuhan
# Processing Record 14 of Set 13 | ambon
# Processing Record 15 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 16 of Set 13 | pangnirtung
# Processing Record 17 of Set 13 | palencia
# Processing Record 18 of Set 13 | kitui
# Processing Record 19 of Set 13 | riyadh
# Processing Record 20 of Set 13 | yukhnov
# Processing Record 21 of Set 13 | batken
# Processing Record 22 of Set 13 | nador
# Processing Record 23 of Set 13 | port-gentil
# Processing Record 24 of Set 13 | bubaque
# Processing Record 25 of Set 13 | oum hadjer
# Processing Record 26 of Set 13 | ketchikan
# Processing Record 27 of Set 13 | camopi
# Processing Record 28 of Set 13 | gamba
# Processing Record 29 of Set 13 | ponta delgada
# Processing Record 30 of Set 13 | sovetskiy
# Processing Record 31 of Set 13 | mahibadhoo
# Processing Record 32 of Set 13 | oistins
# Processing Record 33 of Set 13 | bronnoysund
# Processing Record 34 of Set 13 | wau
# Processing Record 35 of Set 13 | norfolk
# Processing Record 36 of Set 13 | lucapa
# Processing Record 37 of Set 13 | trairi
# Processing Record 38 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 13 | erdenet
# Processing Record 40 of Set 13 | lehututu
# Processing Record 41 of Set 13 | isabela
# Processing Record 42 of Set 13 | nome
# Processing Record 43 of Set 13 | tacuati
# Processing Record 44 of Set 13 | ler
# Processing Record 45 of Set 13 | bogorodskoye
# Processing Record 46 of Set 13 | terrace
# Processing Record 47 of Set 13 | rabo de peixe
# Processing Record 48 of Set 13 | cockburn town
# Processing Record 49 of Set 13 | aksu
# Processing Record 50 of Set 13 | cambridge
# Processing Record 1 of Set 14 | dicabisagan
# Processing Record 2 of Set 14 | bor
# Processing Record 3 of Set 14 | maragogi
# Processing Record 4 of Set 14 | sabha
# Processing Record 5 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 14 | rock sound
# Processing Record 7 of Set 14 | chudovo
# Processing Record 8 of Set 14 | zaoyang
# Processing Record 9 of Set 14 | itarema
# Processing Record 10 of Set 14 | ebebiyin
# Processing Record 11 of Set 14 | puri
# Processing Record 12 of Set 14 | ahipara
# Processing Record 13 of Set 14 | novikovo
# Processing Record 14 of Set 14 | tortoli
# Processing Record 15 of Set 14 | olga
# Processing Record 16 of Set 14 | ankang
# Processing Record 17 of Set 14 | boundiali
# Processing Record 18 of Set 14 | tual
# Processing Record 19 of Set 14 | colonia
# Processing Record 20 of Set 14 | sicuani
# Processing Record 21 of Set 14 | plouzane
# Processing Record 22 of Set 14 | smithers
# Processing Record 23 of Set 14 | anloga
# Processing Record 24 of Set 14 | cap-aux-meules
# Processing Record 25 of Set 14 | bintulu
# Processing Record 26 of Set 14 | batemans bay
# Processing Record 27 of Set 14 | mragowo
# Processing Record 28 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 14 | knysna
# Processing Record 30 of Set 14 | amuntai
# Processing Record 31 of Set 14 | hasaki
# Processing Record 32 of Set 14 | ayan
# Processing Record 33 of Set 14 | manavalakurichi
# Processing Record 34 of Set 14 | puli
# Processing Record 35 of Set 14 | rawlins
# Processing Record 36 of Set 14 | te anau
# Processing Record 37 of Set 14 | praia da vitoria
# Processing Record 38 of Set 14 | howard springs
# Processing Record 39 of Set 14 | darfo
# Processing Record 40 of Set 14 | kawalu
# Processing Record 41 of Set 14 | obeliai
# Processing Record 42 of Set 14 | atambua
# Processing Record 43 of Set 14 | bozeman
# Processing Record 44 of Set 14 | reguengos de monsaraz
# Processing Record 45 of Set 14 | aguimes
# Processing Record 46 of Set 14 | tezu
# Processing Record 47 of Set 14 | houma
# Processing Record 48 of Set 14 | oranjestad
# Processing Record 49 of Set 14 | nizwa
# Processing Record 50 of Set 14 | batagay-alyta
# Processing Record 1 of Set 15 | manggar
# Processing Record 2 of Set 15 | port macquarie
# Processing Record 3 of Set 15 | tinos
# Processing Record 4 of Set 15 | dokka
# Processing Record 5 of Set 15 | boden
# Processing Record 6 of Set 15 | baiyin
# Processing Record 7 of Set 15 | zacualtipan
# Processing Record 8 of Set 15 | jalpan
# Processing Record 9 of Set 15 | wa
# City not found. Skipping...
# Processing Record 10 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 15 | beyneu
# Processing Record 12 of Set 15 | chara
# Processing Record 13 of Set 15 | bolilao
# Processing Record 14 of Set 15 | umm lajj
# Processing Record 15 of Set 15 | high level
# Processing Record 16 of Set 15 | saint petersburg
# Processing Record 17 of Set 15 | susangerd
# Processing Record 18 of Set 15 | talalayivka
# Processing Record 19 of Set 15 | saint-pierre
# Processing Record 20 of Set 15 | avondale
# Processing Record 21 of Set 15 | merke
# Processing Record 22 of Set 15 | sergeyevka
# Processing Record 23 of Set 15 | shebalino
# Processing Record 24 of Set 15 | iskilip
# Processing Record 25 of Set 15 | maldonado
# Processing Record 26 of Set 15 | elko
# Processing Record 27 of Set 15 | swabi
# Processing Record 28 of Set 15 | najran
# Processing Record 29 of Set 15 | tessalit
# Processing Record 30 of Set 15 | huangmei
# Processing Record 31 of Set 15 | mattru
# Processing Record 32 of Set 15 | puerto escondido
# Processing Record 33 of Set 15 | nanton
# Processing Record 34 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 35 of Set 15 | yelandur
# Processing Record 36 of Set 15 | hermiston
# Processing Record 37 of Set 15 | promyshlennyy
# Processing Record 38 of Set 15 | nsanje
# Processing Record 39 of Set 15 | beloha
# Processing Record 40 of Set 15 | san quintin
# Processing Record 41 of Set 15 | hay river
# Processing Record 42 of Set 15 | tynda
# Processing Record 43 of Set 15 | aron
# Processing Record 44 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 15 | bobrovka
# Processing Record 46 of Set 15 | bima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Jamestown  42.0970  -79.2353     51.39        91          90
# 1        Cherskiy  68.7500  161.3000     -2.74        99         100
# 2       Saskylakh  71.9167  114.0833      3.78        97          98
# 3         Rikitea -23.1203 -134.9692     72.99        76         100
# 4     Provideniya  64.3833 -173.3000     17.71        62          40
# 5      Chokurdakh  70.6333  147.9167     -6.75        98          94
# 6  Severo-Kurilsk  50.6789  156.1250     36.63        55          72
# 7      Butaritari   3.0707  172.7902     82.62        73           6
# 8         Fortuna  40.5982 -124.1573     61.48        70          90
# 9           Tabuk  17.4189  121.4443     82.85        67          57
#
#    Wind Speed Country Current Description                 Date
# 0        5.01      US     overcast clouds  2021-11-01 04:26:53
# 1        5.53      RU     overcast clouds  2021-11-01 04:19:52
# 2        5.61      RU     overcast clouds  2021-11-01 04:29:38
# 3       16.78      PF     overcast clouds  2021-11-01 04:27:35
# 4       11.18      RU    scattered clouds  2021-11-01 04:18:49
# 5        7.07      RU     overcast clouds  2021-11-01 04:20:50
# 6       24.32      RU          light rain  2021-11-01 04:20:39
# 7       12.24      KI          light rain  2021-11-01 04:15:20
# 8        4.00      US     overcast clouds  2021-11-01 04:20:10
# 9        4.72      PH       broken clouds  2021-11-01 04:29:40

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
